# %% [markdown]
# Universidad de Nariño Maestría en Gestión de Tecnologías de Información y Conocimiento Electiva Aprendizaje Automático
#
# Michel Daniela Bravo
# Tatiana Maya Pianda
#
#                                                      Guía 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos=pd.read_csv("D:\Mgtic\Machine Learning\Clase 2\Ecaes.csv",sep="|")
datos.head(20)
# Out:
#    ESTU_CONSECUTIVO ESTU_GENERO ESTU_ESTADOCIVIL  \
# 0    EK201830019157           M          SOLTERO
# 1    EK201830019637           M          SOLTERO
# 2    EK201830019002           M          SOLTERO
# 3    EK201830018275           F          SOLTERO
# 4    EK201830018873           M          SOLTERO
# 5    EK201830019897           M          SOLTERO
# 6    EK201830005358           M          SOLTERO
# 7    EK201830016227           M          SOLTERO
# 8    EK201830004352           M          SOLTERO
# 9    EK201830015701           M          SOLTERO
# 10   EK201830018623           M          SOLTERO
# 11   EK201830018471           M          SOLTERO
# 12   EK201830016049           F          SOLTERO
# 13   EK201830018820           M          SOLTERO
# 14   EK201830011238           F          SOLTERO
# 15   EK201830015665           F          SOLTERO
# 16   EK201830004265           F           Casado
# 17   EK201830015882           M          SOLTERO
# ...

# %% [raw]
# 1. ¿Cuáles variables de la base le parecen categóricas?

# %%
datos.dtypes
# Out:
# ESTU_CONSECUTIVO             object
# ESTU_GENERO                  object
# ESTU_ESTADOCIVIL             object
# FAMI_HOGARACTUAL             object
# FAMI_CABEZAFAMILIA           object
# FAMI_NUMPERSONASACARGO        int64
# FAMI_ESTRATOVIVIENDA          int64
# FAMI_PERSONASHOGAR            int64
# FAMI_CUARTOSHOGAR             int64
# FAMI_TIENECOMPUTADOR         object
# ESTU_HORASSEMANATRABAJA      object
# INST_NOMBRE_INSTITUCION      object
# ESTU_PRGM_DEPARTAMENTO       object
# ESTU_PRGM_ACADEMICO          object
# MOD_RAZONA_CUANTITAT_PUNT     int64
# MOD_LECTURA_CRITICA_PUNT      int64
# MOD_COMPETEN_CIUDADA_PUNT     int64
# MOD_INGLES_PUNT               int64
# PUNT_GLOBAL                   int64
# dtype: object

# %%
R/ Variables categóricas:
    ESTU_GENERO
    ESTU_ESTADOCIVIL
    FAMI_HOGARACTUAL 
    FAMI_CABEZAFAMILIA
    FAMI_TIENECOMPUTADOR
    ESTU_HORASSEMANATRABAJA
    INST_NOMBRE_INSTITUCION
    ESTU_PRGM_DEPARTAMENTO
    ESTU_PRGM_ACADEMICO

# %% [raw]
# 2. ¿Cuáles variables de la base le parecen cuantitativas discretas?

# %%
R/
FAMI_NUMPERSONASACARGO
FAMI_ESTRATOVIVIENDA
FAMI_PERSONASHOGAR 
FAMI_CUARTOSHOGAR

# %% [raw]
# 3. ¿Cuáles variables de la base le parecen cuantitativas continuas?

# %%
R/
MOD_RAZONA_CUANTITAT_PUNT
MOD_LECTURA_CRITICA_PUNT 
MOD_COMPETEN_CIUDADA_PUNT
MOD_INGLES_PUNT
PUNT_GLOBAL

# %% [raw]
# 4. Construir la tabla de frecuencias y un diagrama de barras de las variables categóricas y
# las cuantitativas discretas.

# %%
print("\n",datos.groupby('ESTU_GENERO').count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby('ESTU_ESTADOCIVIL').count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby('FAMI_HOGARACTUAL').count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby('FAMI_CABEZAFAMILIA').count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['FAMI_TIENECOMPUTADOR']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['ESTU_HORASSEMANATRABAJA']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['INST_NOMBRE_INSTITUCION']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['ESTU_PRGM_DEPARTAMENTO']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['ESTU_PRGM_ACADEMICO']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['FAMI_NUMPERSONASACARGO']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['FAMI_ESTRATOVIVIENDA']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['FAMI_PERSONASHOGAR']).count()['ESTU_CONSECUTIVO'])
print("\n",datos.groupby(['FAMI_CUARTOSHOGAR']).count()['ESTU_CONSECUTIVO'])
# Out:
#  ESTU_GENERO
# F     89
# M    131
# Name: ESTU_CONSECUTIVO, dtype: int64
#
#  ESTU_ESTADOCIVIL
# Casado           1
# SOLTERO        214
# UNIÓN_LIBRE      5
# Name: ESTU_CONSECUTIVO, dtype: int64
#
#  FAMI_HOGARACTUAL
# Es habitual o permanente              148
# Es temporal por razones de estudio     72
# Name: ESTU_CONSECUTIVO, dtype: int64
#
#  FAMI_CABEZAFAMILIA
# No    207
# Si     13
# Name: ESTU_CONSECUTIVO, dtype: int64
#
#  FAMI_TIENECOMPUTADOR
# No                      25
# No sabe no responde     12
# Si                     183
# Name: ESTU_CONSECUTIVO, dtype: int64
#
#  ESTU_HORASSEMANATRABAJA
# 0                      51
# Entre 11 y 20 horas    56
# Entre 21 y 30 horas    29
# Menos de 10 horas      49
# Más de 30 horas        23
# No sabe no responde    12
# Name: ESTU_CONSECUTIVO, dtype: int64
#
#  INST_NOMBRE_INSTITUCION
# UNIVERSIDAD DE NARIÑO-PASTO    220
# Name: ESTU_CONSECUTIVO, dtype: int64
#
#  ESTU_PRGM_DEPARTAMENTO
# NARIÑO    220
# ...

# %%
datos.groupby('ESTU_GENERO').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Genero')
plt.show()

datos.groupby('ESTU_ESTADOCIVIL').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras estado civil')
plt.show()

datos.groupby('FAMI_HOGARACTUAL').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras pacientes embarazadas')
plt.show()

datos.groupby('FAMI_CABEZAFAMILIA').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Cabeza de familia')
plt.show()

datos.groupby('FAMI_TIENECOMPUTADOR').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Familia tiene computador')
plt.show()

datos.groupby('ESTU_HORASSEMANATRABAJA').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Horas que trabaja en semana')
plt.show()

datos.groupby('INST_NOMBRE_INSTITUCION').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Nombre institución')
plt.show()

datos.groupby('ESTU_PRGM_DEPARTAMENTO').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Programa departamento')
plt.show()

datos.groupby('ESTU_PRGM_ACADEMICO').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Programa académico')
plt.show()

datos.groupby('FAMI_NUMPERSONASACARGO').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Número de personas a cargo')
plt.show()

datos.groupby('FAMI_ESTRATOVIVIENDA').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Estrato vivienda')
plt.show()

datos.groupby('FAMI_PERSONASHOGAR').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Personas en el hogar')
plt.show()

datos.groupby('FAMI_CUARTOSHOGAR').count()["ESTU_CONSECUTIVO"].plot(kind='bar',title='diagrama de barras Cuartos en el hogar')
plt.show()

# %% [raw]
# 5. Calcular las medidas de resumen de las variables cuantitativas

# %%
datos.drop(columns=['ESTU_CONSECUTIVO']).describe()
# Out:
#        FAMI_NUMPERSONASACARGO  FAMI_ESTRATOVIVIENDA  FAMI_PERSONASHOGAR  \
# count              220.000000            220.000000          220.000000
# mean                 0.259091              1.572727            4.477273
# std                  0.740948              0.921177            1.588898
# min                  0.000000              0.000000            1.000000
# 25%                  0.000000              1.000000            4.000000
# 50%                  0.000000              1.000000            4.000000
# 75%                  0.000000              2.000000            5.000000
# max                  5.000000              5.000000           11.000000
#
#        FAMI_CUARTOSHOGAR  MOD_RAZONA_CUANTITAT_PUNT  MOD_LECTURA_CRITICA_PUNT  \
# count         220.000000                 220.000000                220.000000
# mean            2.936364                 170.740909                154.931818
# std             1.031710                  32.450189                 30.701537
# ...

# %% [raw]
# 6. Confirme la presencia de outliers graficando los boxplot de cada variable cuantitativa.

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Número de personas a cargo')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.FAMI_NUMPERSONASACARGO, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe5e93a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe5e9a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe5e9040>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fe5e5160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fe5e54c0>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Estrato vivienda')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.FAMI_ESTRATOVIVIENDA, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe632370>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe58a340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe632a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fe58abe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fe62d370>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Numero de personas que viven en el hogar')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.FAMI_PERSONASHOGAR, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe6d44c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe9f54c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe6d4a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fe9f56a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fe9f5b20>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Numero de cuartos en el hogar')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.FAMI_CUARTOSHOGAR, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe73f7c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fdccdbb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe73f3a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fdccdd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fe539340>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Razonamiento cunatitaivo')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.MOD_RAZONA_CUANTITAT_PUNT, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe55da30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe55dd30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe55d730>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fdd86dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fdd86d00>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Lectura crítica')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.MOD_LECTURA_CRITICA_PUNT, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe645250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe6bdd60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe645cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fe6bd790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fe6dd1c0>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Competencia ciudadana')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.MOD_COMPETEN_CIUDADA_PUNT, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe790820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe7903d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe77f430>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fe9c6700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fe9c6d30>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Inglés')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.MOD_INGLES_PUNT, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe674d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe674190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fdcc4580>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fe674940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fdd7cdf0>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Puntaje global')
fig3.set_size_inches(10,5)
ax3.boxplot(datos.PUNT_GLOBAL, flierprops=green_diamond,widths=0.3,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x290fe5a1460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x290fe5a1b20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x290fe5a1160>],
#  'medians': [<matplotlib.lines.Line2D at 0x290fe5a4220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x290fe5a45b0>],
#  'means': []}

# %% [raw]
# 7. ¿Cuáles de las variables le parecen simétricas a partir de estos resúmenes? Confirme
# estas observaciones mediante un boxplot.
# R/ La variables simétricas serían el puntaje global y lectura crítica

# %% [raw]
# 8. Encuentre outliers moderados y severos de cada variable cuantitativa continua.

# %%
def detecta_oulier(df,variable,registro):
    q3=df[variable].quantile(0.75)
    q1=df[variable].quantile(0.25)

    di=q3-q1

    outsupModerado1=q3+1.5*di
    outsupModerado2=q3+3*di

    outinfModerado1=q1-(1.5*di)
    outinfModerado2=q1-(3*di)

    filtrosup1=df[variable]>=outsupModerado1
    filtrosup2=df[variable]<=outsupModerado2
    
    filtroinf1=df[variable]<=outinfModerado1
    filtroinf2=df[variable]>=outinfModerado2

    filtrosup3=df[variable]>outsupModerado2
    filtroinf3=df[variable]<outinfModerado2

    if len(df[filtrosup1 & filtrosup2])>0:
        print("outliers moderados q3:",len(df[filtrosup1 & filtrosup2]))
        display(df[filtrosup1 & filtrosup2][[variable,registro]])
    if len(df[filtrosup3])>0:
        print("outliers severos q3:",len(df[filtrosup3]))
        display(df[filtrosup3][[variable,registro]])
    if len(df[filtroinf1 & filtroinf2])>0:
        print("outliers moderados q1:", len(df[filtroinf1 & filtroinf2]))
        display(df[filtroinf1 & filtroinf2][[variable,registro]])
    if len(df[filtroinf3]):
        print("outliers severos q1:",len(df[filtroinf3]))
        display(df[filtroinf3][[variable,registro]])
    return(df[filtrosup1 & filtrosup2],df[filtrosup3],
           df[filtroinf1 & filtroinf2],df[filtroinf3]
          )

# %%
print("Razonamiento cuantitativo")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'MOD_RAZONA_CUANTITAT_PUNT','ESTU_CONSECUTIVO')
# Out:
# Razonamiento cuantitativo
# outliers moderados q3: 2
#     MOD_RAZONA_CUANTITAT_PUNT ESTU_CONSECUTIVO
# 31                        300   EK201830005036
# 37                        300   EK201830056688
# outliers moderados q1: 4
#      MOD_RAZONA_CUANTITAT_PUNT ESTU_CONSECUTIVO
# 85                          88   EK201830019808
# 173                         85   EK201830018809
# 197                         81   EK201830218969
# 219                         76   EK201830017153

# %%
print("Lectura crítica")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'MOD_LECTURA_CRITICA_PUNT','ESTU_CONSECUTIVO')
# Out:
# Lectura crítica

# %%
print("Competencia ciudadna")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'MOD_COMPETEN_CIUDADA_PUNT','ESTU_CONSECUTIVO')
# Out:
# Competencia ciudadna
# outliers moderados q1: 1
#     MOD_COMPETEN_CIUDADA_PUNT ESTU_CONSECUTIVO
# 79                          0   EK201830020748

# %%
print("Inglés")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'MOD_INGLES_PUNT','ESTU_CONSECUTIVO')
# Out:
# Inglés
# outliers severos q1: 1
#      MOD_INGLES_PUNT ESTU_CONSECUTIVO
# 105                0   EK201830035043

# %%
print("Puntaje global")    
sevq3,modq3,modq1,sevq3=detecta_oulier(datos,'PUNT_GLOBAL','ESTU_CONSECUTIVO')
# Out:
# Puntaje global
# outliers moderados q3: 1
#     PUNT_GLOBAL ESTU_CONSECUTIVO
# 31          215   EK201830005036
# outliers moderados q1: 1
#      PUNT_GLOBAL ESTU_CONSECUTIVO
# 197           89   EK201830218969

# %% [raw]
# 9. Realizar un boxplot comparativo para el puntaje global discriminando por la variable
# género. ¿Qué genero obtuvo mejores resultados?

# %%
data = [datos[datos['ESTU_GENERO']=="F"].PUNT_GLOBAL, datos[datos['ESTU_GENERO']=="M"].PUNT_GLOBAL]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo género')
ax7.boxplot(data)
plt.show()

# %% [raw]
# R/ el género que obtuvo mejores puntajes es el masculino.

# %% [raw]
# 10. Realizar un boxplot comparativo para el puntaje global discriminando por la variable
# FAMI_ESTRATOVIVIENDA. ¿Qué estrato obtuvo mejores resultados? ¿Cuál tiene una
# mediana mayor?

# %%
data = [datos[datos['FAMI_ESTRATOVIVIENDA']==0].PUNT_GLOBAL, datos[datos['FAMI_ESTRATOVIVIENDA']==1].PUNT_GLOBAL, datos[datos['FAMI_ESTRATOVIVIENDA']==2].PUNT_GLOBAL, datos[datos['FAMI_ESTRATOVIVIENDA']==3].PUNT_GLOBAL, datos[datos['FAMI_ESTRATOVIVIENDA']==4].PUNT_GLOBAL, datos[datos['FAMI_ESTRATOVIVIENDA']==5].PUNT_GLOBAL]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo Estrato')
ax7.boxplot(data)
plt.show()

# %% [raw]
# R/ El estrato con mejores resultados y mayor mediana es el 4 .

# %% [raw]
# 11. Realizar un boxplot comparativo para el puntaje de razonamiento cuantitativo
# discriminados por programa. ¿Qué programa obtuvo mejores resultados en la prueba?

# %%
data = [datos[datos['ESTU_PRGM_ACADEMICO']=="INGENIERIA AGROFORESTAL"].MOD_RAZONA_CUANTITAT_PUNT, datos[datos['ESTU_PRGM_ACADEMICO']=="INGENIERIA AGRONOMICA"].MOD_RAZONA_CUANTITAT_PUNT, datos[datos['ESTU_PRGM_ACADEMICO']=="INGENIERIA AMBIENTAL"].MOD_RAZONA_CUANTITAT_PUNT, datos[datos['ESTU_PRGM_ACADEMICO']=="INGENIERIA CIVIL"].MOD_RAZONA_CUANTITAT_PUNT, datos[datos['ESTU_PRGM_ACADEMICO']=="INGENIERIA DE SISTEMAS"].MOD_RAZONA_CUANTITAT_PUNT, datos[datos['ESTU_PRGM_ACADEMICO']=="INGENIERIA ELECTRONICA"].MOD_RAZONA_CUANTITAT_PUNT, datos[datos['ESTU_PRGM_ACADEMICO']=="INGENIERIA EN PRODUCCION ACUICOLA"].MOD_RAZONA_CUANTITAT_PUNT]
fig7, ax7 = plt.subplots()
ax7.set_title('boxplot comparativo Programa Académico')
ax7.boxplot(data)
plt.show()

# %% [raw]
# R/ el programa que obtivo mejores resultados en la prueba de razonamiento cuantitativo fue Ingeneiría Electrónica.

# %% [raw]
# 12. Hallar las matrices de varianzas y covarianzas y de correlaciones.

# %%
datos.drop(columns=['ESTU_CONSECUTIVO']).cov()
# Out:
#                            FAMI_NUMPERSONASACARGO  FAMI_ESTRATOVIVIENDA  \
# FAMI_NUMPERSONASACARGO                   0.549004             -0.130801
# FAMI_ESTRATOVIVIENDA                    -0.130801              0.848568
# FAMI_PERSONASHOGAR                       0.035596             -0.046285
# FAMI_CUARTOSHOGAR                       -0.015401              0.022914
# MOD_RAZONA_CUANTITAT_PUNT               -0.608364              4.614819
# MOD_LECTURA_CRITICA_PUNT                -3.484537              6.331465
# MOD_COMPETEN_CIUDADA_PUNT               -1.284496              4.644126
# MOD_INGLES_PUNT                         -5.171544              6.132213
# PUNT_GLOBAL                             -2.237775              4.718804
#
#                            FAMI_PERSONASHOGAR  FAMI_CUARTOSHOGAR  \
# FAMI_NUMPERSONASACARGO               0.035596          -0.015401
# FAMI_ESTRATOVIVIENDA                -0.046285           0.022914
# ...

# %%
datos.drop(columns=['ESTU_CONSECUTIVO']).corr()
# Out:
#                            FAMI_NUMPERSONASACARGO  FAMI_ESTRATOVIVIENDA  \
# FAMI_NUMPERSONASACARGO                   1.000000             -0.191638
# FAMI_ESTRATOVIVIENDA                    -0.191638              1.000000
# FAMI_PERSONASHOGAR                       0.030235             -0.031623
# FAMI_CUARTOSHOGAR                       -0.020146              0.024110
# MOD_RAZONA_CUANTITAT_PUNT               -0.025302              0.154381
# MOD_LECTURA_CRITICA_PUNT                -0.153178              0.223873
# MOD_COMPETEN_CIUDADA_PUNT               -0.049025              0.142570
# MOD_INGLES_PUNT                         -0.232314              0.221573
# PUNT_GLOBAL                             -0.134775              0.228597
#
#                            FAMI_PERSONASHOGAR  FAMI_CUARTOSHOGAR  \
# FAMI_NUMPERSONASACARGO               0.030235          -0.020146
# FAMI_ESTRATOVIVIENDA                -0.031623           0.024110
# ...

# %% [raw]
# 13. Graficar un dispersograma y un mapa de calor con la matriz de correlaciones.
# ¿Qué variables están correlacionadas positivamente?, ¿cuáles negativamente? y
# ¿cuáles consideran que no tienen correlación?

# %%
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
sns.pairplot(datos.drop(columns=['ESTU_CONSECUTIVO']))
plt.show()

# %%
p1 = sns.heatmap(datos[['FAMI_NUMPERSONASACARGO','FAMI_ESTRATOVIVIENDA','FAMI_PERSONASHOGAR','FAMI_CUARTOSHOGAR','MOD_RAZONA_CUANTITAT_PUNT','MOD_LECTURA_CRITICA_PUNT','MOD_COMPETEN_CIUDADA_PUNT','MOD_INGLES_PUNT','PUNT_GLOBAL']].corr(),annot=True, annot_kws={"size": 7},
                cmap='PuOr')

# %% [raw]
# R/ La variable FAMI_NUMPERSONASACARGO solo tiene correlación positiva con FAMI_PERSONASHOGAR, con las demás         tiene una correlación negativa.
#    La variable FAMI_ESTRATOVIVIENDA solo tiene correlación negativa con FAMI_NUMPERSONASACARGO y con                FAMI_PERSONASHOGAR, con las demás variables tiene una correlación positiva.
#    La variable FAMI_PERSONASHOGAR tiene correlación positiva con FAMI_NUMPERSONASACARGO, FAMI_CUARTOSHOGAR y       MOD_COMPETEN_CIUDADA_PUNT, con las demás variables tiene una correlación negativa.
#    La variable FAMI_CUARTOSHOGAR tiene correlación positiva con todas las variables excepto:                       FAMI_NUMPERSONASACARGO
#    La variable MOD_RAZONA_CUANTITAT_PUNT tiene correlación negativa con FAMI_NUMPERSONASACARGO y                   FAMI_PERSONASHOGAR con las demás variables tiene una correlación postiva.
#    La variable MOD_LECTURA_CRITICA_PUNT tiene correlación negativa con FAMI_NUMPERSONASACARGO y                     FAMI_PERSONASHOGAR con las demás variables tiene una correlación postiva.
#    La variable MOD_COMPETEN_CIUDADA_PUNT solo tiene correlación negativa con FAMI_NUMPERSONASACARGO, con las       demás variables tiene una correlación postiva.
#    La variable MOD_INGLES_PUNT tiene correlación negativa con FAMI_NUMPERSONASACARGO y                             FAMI_PERSONASHOGAR con las demás variables tiene una correlación postiva.
#    La variable PUNT_GLOBAL tiene correlación negativa con FAMI_NUMPERSONASACARGO y                                 FAMI_PERSONASHOGAR con las demás variables tiene una correlación postiva.
#
#   -- Ningun conjunto de las variables no tiene correlación.
